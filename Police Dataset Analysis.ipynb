# %% [markdown]
# # Police Dataset
# ###        Analysis of Police Dataset with pandas.

# %%
import pandas as pd

# %%
Police = pd.read_csv(r'E:\DOWNLOAD\Portfolio Content\Python Files\3. Police Data.csv')

# %%
Police.head()
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
# 2  1/23/2005     23:15           NaN             M          1972.0
# 3  2/20/2005     17:15           NaN             M          1986.0
# 4  3/14/2005     10:00           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %% [markdown]
# ###  1. Remove the column that contains only missing values.

# %%
Police.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
Police.drop(columns = "country_name",inplace= True)

# %%
Police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted search_type stop_outcome  \
# 0      Speeding  Speeding             False         NaN     Citation
# 1      Speeding  Speeding             False         NaN     Citation
#
#   is_arrested stop_duration  drugs_related_stop
# 0       False      0-15 Min               False
# 1       False      0-15 Min               False

# %% [markdown]
# ### 2. For Speeding , How many instances were recorded for each Gender type?

# %%
Police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted search_type stop_outcome  \
# 0      Speeding  Speeding             False         NaN     Citation
# 1      Speeding  Speeding             False         NaN     Citation
#
#   is_arrested stop_duration  drugs_related_stop
# 0       False      0-15 Min               False
# 1       False      0-15 Min               False

# %%
Police[(Police["violation_raw"] == 'Speeding')].driver_gender.value_counts()
# Out:
# M    25517
# F    11686
# Name: driver_gender, dtype: int64

# %% [markdown]
# ### 3. Does gender affect who gets searched during a stop ?

# %%
Police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted search_type stop_outcome  \
# 0      Speeding  Speeding             False         NaN     Citation
# 1      Speeding  Speeding             False         NaN     Citation
#
#   is_arrested stop_duration  drugs_related_stop
# 0       False      0-15 Min               False
# 1       False      0-15 Min               False

# %%
Police.groupby("driver_gender").search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %% [markdown]
# ### 4. What is the mean stop_duration ?

# %%
Police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted search_type stop_outcome  \
# 0      Speeding  Speeding             False         NaN     Citation
# 1      Speeding  Speeding             False         NaN     Citation
#
#   is_arrested  stop_duration  drugs_related_stop
# 0       False            NaN               False
# 1       False            NaN               False

# %%
Police["stop_duration"].value_counts()
# Out:
# 0-15 Min     47379
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: stop_duration, dtype: int64

# %%
Police["stop_duration"] = Police["stop_duration"].map({"0-15 Min" : 7.5, "16-30 Min" : 24, "30+ Min": 45})

# %%
Police["stop_duration"].mean()
# Out:
# 12.187420698181345

# %% [markdown]
# ### 5. Compare the age distributions for each violation.

# %%
Police.head(2)
Police.rename(columns = {"driver_age" : "driver age"}, inplace= True)
Police.head(2)
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
#
#    driver age driver_race violation_raw violation  search_conducted  \
# 0        20.0       White      Speeding  Speeding             False
# 1        40.0       White      Speeding  Speeding             False
#
#   search_type stop_outcome is_arrested  stop_duration  drugs_related_stop
# 0         NaN     Citation       False            7.5               False
# 1         NaN     Citation       False            7.5               False

# %%
Police.groupby("violation_raw")["driver age"].describe()
# Out:
#                                     count       mean        std   min    25%  \
# violation_raw
# APB                                  50.0  35.360000  11.547170  18.0  26.00
# Call for Service                    786.0  33.717557  13.153832  16.0  23.00
# Equipment/Inspection Violation     6507.0  31.682957  11.380671  16.0  23.00
# Motorist Assist/Courtesy            127.0  35.464567  12.424244  17.0  25.00
# Other Traffic Violation           11876.0  36.736443  13.258350  15.0  25.00
# Registration Violation             2240.0  32.656696  11.150780  16.0  24.00
# Seatbelt Violation                    3.0  30.333333  10.214369  23.0  24.50
# Special Detail/Directed Patrol     2298.0  43.549608  11.430333  17.0  35.00
# Speeding                          37120.0  33.262581  12.615781  15.0  23.00
# Suspicious Person                    36.0  32.055556  12.741259  18.0  22.75
# Violation of City/Town Ordinance    170.0  35.311765  12.532674  18.0  24.00
# ...
